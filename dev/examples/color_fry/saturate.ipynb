# %% [markdown]
# # It's saturated

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.saturate(fabio)
save("assets/saturate.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.098,0.149)  …  RGB{N0f8}(0.043,0.157,0.235)
#  RGB{N0f8}(0.459,0.118,0.086)     RGB{N0f8}(0.043,0.153,0.231)
#  RGB{N0f8}(0.51,0.165,0.094)      RGB{N0f8}(0.043,0.153,0.227)
#  RGB{N0f8}(0.455,0.216,0.082)     RGB{N0f8}(0.043,0.153,0.227)
#  RGB{N0f8}(0.435,0.2,0.078)       RGB{N0f8}(0.039,0.149,0.224)
#  RGB{N0f8}(0.467,0.118,0.086)  …  RGB{N0f8}(0.039,0.149,0.224)
#  RGB{N0f8}(0.482,0.145,0.09)      RGB{N0f8}(0.043,0.153,0.227)
#  RGB{N0f8}(0.455,0.227,0.082)     RGB{N0f8}(0.043,0.153,0.227)
#  RGB{N0f8}(0.431,0.184,0.078)     RGB{N0f8}(0.039,0.149,0.224)
#  RGB{N0f8}(0.435,0.184,0.078)     RGB{N0f8}(0.039,0.145,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.867,0.435,0.161)     RGB{N0f8}(0.831,0.325,0.153)
#  RGB{N0f8}(0.624,0.553,0.114)     RGB{N0f8}(0.851,0.208,0.157)
#  RGB{N0f8}(0.498,0.161,0.09)      RGB{N0f8}(0.871,0.231,0.161)
#  RGB{N0f8}(0.482,0.239,0.09)   …  RGB{N0f8}(0.871,0.302,0.161)
#  RGB{N0f8}(0.573,0.443,0.106)     RGB{N0f8}(0.89,0.349,0.165)
#  RGB{N0f8}(0.576,0.431,0.106)     RGB{N0f8}(0.898,0.388,0.165)
#  RGB{N0f8}(0.659,0.361,0.122)     RGB{N0f8}(0.906,0.416,0.165)
#  RGB{N0f8}(0.749,0.427,0.137)     RGB{N0f8}(0.925,0.431,0.169)
#  RGB{N0f8}(0.663,0.498,0.122)  …  RGB{N0f8}(0.89,0.412,0.165)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
