# %% [markdown]
# # It's saturated

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.saturate(fabio)
save("assets/saturate.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.035,0.094)  …  RGB{N0f8}(0.016,0.145,0.235)
#  RGB{N0f8}(0.459,0.071,0.031)     RGB{N0f8}(0.016,0.145,0.231)
#  RGB{N0f8}(0.51,0.118,0.035)      RGB{N0f8}(0.016,0.141,0.227)
#  RGB{N0f8}(0.455,0.18,0.031)      RGB{N0f8}(0.016,0.141,0.227)
#  RGB{N0f8}(0.435,0.165,0.031)     RGB{N0f8}(0.016,0.137,0.224)
#  RGB{N0f8}(0.467,0.071,0.031)  …  RGB{N0f8}(0.016,0.137,0.224)
#  RGB{N0f8}(0.482,0.098,0.031)     RGB{N0f8}(0.016,0.141,0.227)
#  RGB{N0f8}(0.455,0.196,0.031)     RGB{N0f8}(0.016,0.141,0.227)
#  RGB{N0f8}(0.431,0.149,0.027)     RGB{N0f8}(0.016,0.137,0.224)
#  RGB{N0f8}(0.435,0.149,0.031)     RGB{N0f8}(0.016,0.137,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.867,0.376,0.059)     RGB{N0f8}(0.831,0.251,0.055)
#  RGB{N0f8}(0.624,0.545,0.043)     RGB{N0f8}(0.851,0.118,0.059)
#  RGB{N0f8}(0.498,0.11,0.035)      RGB{N0f8}(0.871,0.141,0.059)
#  RGB{N0f8}(0.482,0.204,0.031)  …  RGB{N0f8}(0.871,0.22,0.059)
#  RGB{N0f8}(0.573,0.424,0.039)     RGB{N0f8}(0.89,0.271,0.059)
#  RGB{N0f8}(0.576,0.412,0.039)     RGB{N0f8}(0.898,0.318,0.063)
#  RGB{N0f8}(0.659,0.318,0.043)     RGB{N0f8}(0.906,0.345,0.063)
#  RGB{N0f8}(0.749,0.38,0.051)      RGB{N0f8}(0.925,0.361,0.063)
#  RGB{N0f8}(0.663,0.475,0.043)  …  RGB{N0f8}(0.89,0.345,0.059)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
