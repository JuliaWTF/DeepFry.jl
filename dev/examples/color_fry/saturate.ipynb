# %% [markdown]
# # It's saturated

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.saturate(fabio)
save("assets/saturate.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.063,0.118)  …  RGB{N0f8}(0.027,0.149,0.235)
#  RGB{N0f8}(0.459,0.09,0.055)      RGB{N0f8}(0.027,0.149,0.231)
#  RGB{N0f8}(0.51,0.137,0.063)      RGB{N0f8}(0.027,0.145,0.227)
#  RGB{N0f8}(0.455,0.196,0.055)     RGB{N0f8}(0.027,0.145,0.227)
#  RGB{N0f8}(0.435,0.18,0.051)      RGB{N0f8}(0.027,0.141,0.224)
#  RGB{N0f8}(0.467,0.09,0.055)   …  RGB{N0f8}(0.027,0.141,0.224)
#  RGB{N0f8}(0.482,0.122,0.059)     RGB{N0f8}(0.027,0.145,0.227)
#  RGB{N0f8}(0.455,0.208,0.055)     RGB{N0f8}(0.027,0.145,0.227)
#  RGB{N0f8}(0.431,0.165,0.051)     RGB{N0f8}(0.027,0.141,0.224)
#  RGB{N0f8}(0.435,0.165,0.051)     RGB{N0f8}(0.027,0.141,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.867,0.404,0.102)     RGB{N0f8}(0.831,0.282,0.098)
#  RGB{N0f8}(0.624,0.549,0.075)     RGB{N0f8}(0.851,0.157,0.102)
#  RGB{N0f8}(0.498,0.133,0.059)     RGB{N0f8}(0.871,0.184,0.102)
#  RGB{N0f8}(0.482,0.22,0.059)   …  RGB{N0f8}(0.871,0.255,0.102)
#  RGB{N0f8}(0.573,0.431,0.067)     RGB{N0f8}(0.89,0.306,0.106)
#  RGB{N0f8}(0.576,0.42,0.071)      RGB{N0f8}(0.898,0.349,0.106)
#  RGB{N0f8}(0.659,0.337,0.078)     RGB{N0f8}(0.906,0.376,0.11)
#  RGB{N0f8}(0.749,0.4,0.09)        RGB{N0f8}(0.925,0.392,0.11)
#  RGB{N0f8}(0.663,0.482,0.078)  …  RGB{N0f8}(0.89,0.376,0.106)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
