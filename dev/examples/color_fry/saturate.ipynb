# %% [markdown]
# # It's saturated

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.saturate(fabio)
save("assets/saturate.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.075,0.125)  …  RGB{N0f8}(0.031,0.153,0.235)
#  RGB{N0f8}(0.459,0.098,0.063)     RGB{N0f8}(0.031,0.149,0.231)
#  RGB{N0f8}(0.51,0.145,0.071)      RGB{N0f8}(0.031,0.149,0.227)
#  RGB{N0f8}(0.455,0.204,0.063)     RGB{N0f8}(0.031,0.149,0.227)
#  RGB{N0f8}(0.435,0.184,0.059)     RGB{N0f8}(0.031,0.145,0.224)
#  RGB{N0f8}(0.467,0.098,0.063)  …  RGB{N0f8}(0.031,0.145,0.224)
#  RGB{N0f8}(0.482,0.125,0.067)     RGB{N0f8}(0.031,0.149,0.227)
#  RGB{N0f8}(0.455,0.216,0.063)     RGB{N0f8}(0.031,0.149,0.227)
#  RGB{N0f8}(0.431,0.169,0.059)     RGB{N0f8}(0.031,0.145,0.224)
#  RGB{N0f8}(0.435,0.169,0.059)     RGB{N0f8}(0.031,0.141,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.867,0.412,0.118)     RGB{N0f8}(0.831,0.294,0.114)
#  RGB{N0f8}(0.624,0.549,0.086)     RGB{N0f8}(0.851,0.173,0.118)
#  RGB{N0f8}(0.498,0.141,0.067)     RGB{N0f8}(0.871,0.196,0.122)
#  RGB{N0f8}(0.482,0.224,0.067)  …  RGB{N0f8}(0.871,0.267,0.122)
#  RGB{N0f8}(0.573,0.435,0.078)     RGB{N0f8}(0.89,0.318,0.122)
#  RGB{N0f8}(0.576,0.424,0.078)     RGB{N0f8}(0.898,0.361,0.122)
#  RGB{N0f8}(0.659,0.345,0.09)      RGB{N0f8}(0.906,0.388,0.125)
#  RGB{N0f8}(0.749,0.408,0.102)     RGB{N0f8}(0.925,0.4,0.125)
#  RGB{N0f8}(0.663,0.486,0.09)   …  RGB{N0f8}(0.89,0.388,0.122)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
