# %% [markdown]
# # Contrast equalizer

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.equalize_contrast(fabio)
save("assets/equalize_contrast.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(1.0,0.988,0.992)  …  RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.086,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.122,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.086,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.067,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.086,0.0,0.0)    …  RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.098,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.082,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.071,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  RGB{N0f8}(0.071,0.0,0.0)       RGB{N0f8}(0.0,0.012,0.047)
#  ⋮                           ⋱  ⋮
#  RGB{N0f8}(1.0,0.973,0.894)     RGB{N0f8}(1.0,0.902,0.776)
#  RGB{N0f8}(1.0,1.0,0.929)       RGB{N0f8}(1.0,0.902,0.875)
#  RGB{N0f8}(0.027,0.0,0.0)       RGB{N0f8}(1.0,0.902,0.863)
#  RGB{N0f8}(0.039,0.0,0.0)    …  RGB{N0f8}(1.0,0.91,0.827)
#  RGB{N0f8}(1.0,1.0,0.867)       RGB{N0f8}(1.0,0.914,0.8)
#  RGB{N0f8}(1.0,0.996,0.855)     RGB{N0f8}(1.0,0.918,0.773)
#  RGB{N0f8}(1.0,0.984,0.918)     RGB{N0f8}(1.0,0.922,0.757)
#  RGB{N0f8}(1.0,0.984,0.918)     RGB{N0f8}(1.0,0.922,0.749)
#  RGB{N0f8}(1.0,0.996,0.855)  …  RGB{N0f8}(1.0,0.922,0.749)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
