# %% [markdown]
# # Chess time

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.rand_checker_warp(fabio)
save("assets/rand_checker_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.259,0.263,0.282)  …  RGB{N0f8}(0.553,0.408,0.306)
#  RGB{N0f8}(0.259,0.263,0.282)     RGB{N0f8}(0.545,0.408,0.306)
#  RGB{N0f8}(0.259,0.263,0.282)     RGB{N0f8}(0.502,0.4,0.31)
#  RGB{N0f8}(0.263,0.267,0.282)     RGB{N0f8}(0.463,0.392,0.314)
#  RGB{N0f8}(0.243,0.251,0.255)     RGB{N0f8}(0.443,0.384,0.302)
#  RGB{N0f8}(0.216,0.224,0.216)  …  RGB{N0f8}(0.439,0.384,0.29)
#  RGB{N0f8}(0.208,0.212,0.192)     RGB{N0f8}(0.443,0.388,0.282)
#  RGB{N0f8}(0.345,0.329,0.318)     RGB{N0f8}(0.506,0.463,0.341)
#  RGB{N0f8}(0.482,0.443,0.439)     RGB{N0f8}(0.569,0.533,0.4)
#  RGB{N0f8}(0.6,0.557,0.553)       RGB{N0f8}(0.604,0.573,0.439)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.635,0.553,0.455)     RGB{N0f8}(0.824,0.447,0.322)
#  RGB{N0f8}(0.682,0.6,0.514)       RGB{N0f8}(0.82,0.443,0.318)
#  RGB{N0f8}(0.725,0.643,0.573)     RGB{N0f8}(0.82,0.439,0.314)
#  RGB{N0f8}(0.725,0.651,0.569)  …  RGB{N0f8}(0.82,0.439,0.314)
#  RGB{N0f8}(0.725,0.651,0.553)     RGB{N0f8}(0.816,0.435,0.31)
#  RGB{N0f8}(0.714,0.651,0.533)     RGB{N0f8}(0.816,0.435,0.306)
#  RGB{N0f8}(0.698,0.635,0.506)     RGB{N0f8}(0.82,0.427,0.29)
#  RGB{N0f8}(0.678,0.624,0.475)     RGB{N0f8}(0.824,0.424,0.278)
#  RGB{N0f8}(0.675,0.62,0.467)   …  RGB{N0f8}(0.824,0.424,0.275)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
