# %% [markdown]
# # Who the hell is Gabor

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gabor_filter(fabio)
save("assets/gabor_filter.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.129,0.09,0.067)   …  RGB{N0f8}(0.047,0.063,0.071)
#  RGB{N0f8}(0.141,0.082,0.047)     RGB{N0f8}(0.047,0.063,0.071)
#  RGB{N0f8}(0.114,0.078,0.086)     RGB{N0f8}(0.039,0.055,0.067)
#  RGB{N0f8}(0.098,0.094,0.106)     RGB{N0f8}(0.039,0.055,0.063)
#  RGB{N0f8}(0.106,0.11,0.082)      RGB{N0f8}(0.043,0.055,0.067)
#  RGB{N0f8}(0.106,0.098,0.047)  …  RGB{N0f8}(0.039,0.055,0.063)
#  RGB{N0f8}(0.086,0.075,0.031)     RGB{N0f8}(0.031,0.047,0.055)
#  RGB{N0f8}(0.102,0.071,0.063)     RGB{N0f8}(0.02,0.039,0.047)
#  RGB{N0f8}(0.141,0.09,0.106)      RGB{N0f8}(0.016,0.035,0.047)
#  RGB{N0f8}(0.161,0.122,0.114)     RGB{N0f8}(0.027,0.039,0.051)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.2,0.224,0.396)       RGB{N0f8}(0.306,0.216,0.118)
#  RGB{N0f8}(0.639,0.576,0.659)     RGB{N0f8}(0.29,0.196,0.114)
#  RGB{N0f8}(0.804,0.698,0.706)     RGB{N0f8}(0.247,0.149,0.09)
#  RGB{N0f8}(0.678,0.58,0.6)     …  RGB{N0f8}(0.231,0.133,0.082)
#  RGB{N0f8}(0.51,0.435,0.49)       RGB{N0f8}(0.247,0.153,0.102)
#  RGB{N0f8}(0.455,0.384,0.455)     RGB{N0f8}(0.259,0.161,0.114)
#  RGB{N0f8}(0.455,0.384,0.455)     RGB{N0f8}(0.259,0.161,0.114)
#  RGB{N0f8}(0.455,0.384,0.455)     RGB{N0f8}(0.259,0.161,0.114)
#  RGB{N0f8}(0.455,0.384,0.455)  …  RGB{N0f8}(0.259,0.161,0.114)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
