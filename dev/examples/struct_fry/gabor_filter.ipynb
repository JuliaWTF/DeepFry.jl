# %% [markdown]
# # Who the hell is Gabor

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gabor_filter(fabio)
save("assets/gabor_filter.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.0,0.035,0.0)      …  RGB{N0f8}(0.02,0.027,0.031)
#  RGB{N0f8}(0.0,0.035,0.008)       RGB{N0f8}(0.02,0.027,0.031)
#  RGB{N0f8}(0.0,0.059,0.118)       RGB{N0f8}(0.02,0.027,0.031)
#  RGB{N0f8}(0.0,0.09,0.137)        RGB{N0f8}(0.02,0.027,0.035)
#  RGB{N0f8}(0.0,0.008,0.008)       RGB{N0f8}(0.024,0.027,0.035)
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(0.02,0.027,0.031)
#  RGB{N0f8}(0.0,0.0,0.035)         RGB{N0f8}(0.02,0.027,0.035)
#  RGB{N0f8}(0.0,0.016,0.086)       RGB{N0f8}(0.024,0.031,0.035)
#  RGB{N0f8}(0.0,0.0,0.055)         RGB{N0f8}(0.024,0.027,0.035)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.02,0.027,0.031)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.49,0.404,0.451)      RGB{N0f8}(0.118,0.067,0.075)
#  RGB{N0f8}(0.498,0.431,0.459)     RGB{N0f8}(0.122,0.071,0.067)
#  RGB{N0f8}(0.196,0.247,0.302)     RGB{N0f8}(0.125,0.078,0.063)
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(0.137,0.09,0.067)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.137,0.09,0.067)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.129,0.082,0.055)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.125,0.078,0.055)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.125,0.078,0.055)
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(0.125,0.078,0.055)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
