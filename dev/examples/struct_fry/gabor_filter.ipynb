# %% [markdown]
# # Who the hell is Gabor

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gabor_filter(fabio)
save("assets/gabor_filter.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.298,0.227,0.204)  …  RGB{N0f8}(0.094,0.129,0.153)
#  RGB{N0f8}(0.306,0.235,0.212)     RGB{N0f8}(0.094,0.129,0.153)
#  RGB{N0f8}(0.275,0.227,0.216)     RGB{N0f8}(0.09,0.125,0.149)
#  RGB{N0f8}(0.267,0.231,0.227)     RGB{N0f8}(0.09,0.125,0.149)
#  RGB{N0f8}(0.275,0.231,0.212)     RGB{N0f8}(0.094,0.129,0.153)
#  RGB{N0f8}(0.286,0.231,0.204)  …  RGB{N0f8}(0.094,0.129,0.153)
#  RGB{N0f8}(0.271,0.227,0.216)     RGB{N0f8}(0.09,0.125,0.149)
#  RGB{N0f8}(0.275,0.231,0.216)     RGB{N0f8}(0.09,0.125,0.149)
#  RGB{N0f8}(0.282,0.239,0.212)     RGB{N0f8}(0.09,0.125,0.149)
#  RGB{N0f8}(0.29,0.243,0.204)      RGB{N0f8}(0.086,0.122,0.145)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.482,0.416,0.341)     RGB{N0f8}(0.584,0.357,0.329)
#  RGB{N0f8}(0.525,0.467,0.38)      RGB{N0f8}(0.584,0.361,0.306)
#  RGB{N0f8}(0.522,0.467,0.4)       RGB{N0f8}(0.596,0.373,0.298)
#  RGB{N0f8}(0.514,0.451,0.416)  …  RGB{N0f8}(0.604,0.38,0.282)
#  RGB{N0f8}(0.514,0.439,0.412)     RGB{N0f8}(0.608,0.388,0.278)
#  RGB{N0f8}(0.522,0.439,0.388)     RGB{N0f8}(0.62,0.4,0.282)
#  RGB{N0f8}(0.569,0.482,0.404)     RGB{N0f8}(0.596,0.376,0.259)
#  RGB{N0f8}(0.569,0.482,0.404)     RGB{N0f8}(0.596,0.376,0.259)
#  RGB{N0f8}(0.569,0.482,0.404)  …  RGB{N0f8}(0.596,0.376,0.259)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
