# %% [markdown]
# # Who the hell is Gabor

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gabor_filter(fabio)
save("assets/gabor_filter.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.804,0.447,0.431)  …  RGB{N0f8}(0.157,0.216,0.255)
#  RGB{N0f8}(0.761,0.427,0.447)     RGB{N0f8}(0.157,0.216,0.255)
#  RGB{N0f8}(0.725,0.353,0.337)     RGB{N0f8}(0.157,0.216,0.255)
#  RGB{N0f8}(0.722,0.294,0.231)     RGB{N0f8}(0.157,0.216,0.255)
#  RGB{N0f8}(0.655,0.286,0.22)      RGB{N0f8}(0.157,0.216,0.255)
#  RGB{N0f8}(0.6,0.322,0.243)    …  RGB{N0f8}(0.153,0.212,0.251)
#  RGB{N0f8}(0.565,0.38,0.247)      RGB{N0f8}(0.149,0.208,0.247)
#  RGB{N0f8}(0.584,0.42,0.227)      RGB{N0f8}(0.145,0.204,0.243)
#  RGB{N0f8}(0.655,0.459,0.251)     RGB{N0f8}(0.141,0.196,0.239)
#  RGB{N0f8}(0.737,0.475,0.31)      RGB{N0f8}(0.133,0.192,0.231)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,0.627,0.506)
#  RGB{N0f8}(1.0,1.0,0.761)         RGB{N0f8}(1.0,0.643,0.486)
#  RGB{N0f8}(0.706,0.478,0.141)     RGB{N0f8}(1.0,0.655,0.478)
#  RGB{N0f8}(0.427,0.196,0.0)    …  RGB{N0f8}(1.0,0.659,0.467)
#  RGB{N0f8}(0.412,0.204,0.0)       RGB{N0f8}(1.0,0.647,0.455)
#  RGB{N0f8}(0.376,0.184,0.0)       RGB{N0f8}(1.0,0.639,0.443)
#  RGB{N0f8}(0.337,0.153,0.0)       RGB{N0f8}(1.0,0.635,0.439)
#  RGB{N0f8}(0.337,0.153,0.0)       RGB{N0f8}(1.0,0.635,0.439)
#  RGB{N0f8}(0.337,0.153,0.0)    …  RGB{N0f8}(1.0,0.635,0.439)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
