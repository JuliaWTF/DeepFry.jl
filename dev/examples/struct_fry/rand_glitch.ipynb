# %% [markdown]
# # Glitch that itch

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.rand_glitch(fabio)
save("assets/rand_glitch.png", img); #hide
img #hide
# Out:
# Corrupt JPEG data: 3579 extraneous bytes before marker 0xd9
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.573,0.494,0.498)  …  RGB{N0f8}(0.208,0.271,0.322)
#  RGB{N0f8}(0.439,0.345,0.337)     RGB{N0f8}(0.204,0.267,0.318)
#  RGB{N0f8}(0.482,0.353,0.318)     RGB{N0f8}(0.2,0.263,0.322)
#  RGB{N0f8}(0.467,0.333,0.294)     RGB{N0f8}(0.196,0.259,0.318)
#  RGB{N0f8}(0.451,0.341,0.298)     RGB{N0f8}(0.192,0.255,0.314)
#  RGB{N0f8}(0.463,0.349,0.318)  …  RGB{N0f8}(0.192,0.255,0.314)
#  RGB{N0f8}(0.471,0.353,0.314)     RGB{N0f8}(0.196,0.259,0.318)
#  RGB{N0f8}(0.455,0.345,0.302)     RGB{N0f8}(0.196,0.259,0.318)
#  RGB{N0f8}(0.439,0.333,0.298)     RGB{N0f8}(0.2,0.251,0.314)
#  RGB{N0f8}(0.435,0.341,0.302)     RGB{N0f8}(0.2,0.251,0.314)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.49,0.78,0.886)       RGB{N0f8}(0.596,0.847,0.855)
#  RGB{N0f8}(0.557,0.824,0.898)     RGB{N0f8}(0.608,0.859,0.898)
#  RGB{N0f8}(0.608,0.863,0.941)     RGB{N0f8}(0.58,0.831,0.871)
#  RGB{N0f8}(0.635,0.89,1.0)     …  RGB{N0f8}(0.506,0.753,0.773)
#  RGB{N0f8}(0.627,0.882,0.992)     RGB{N0f8}(0.51,0.745,0.749)
#  RGB{N0f8}(0.604,0.875,0.937)     RGB{N0f8}(0.557,0.788,0.773)
#  RGB{N0f8}(0.573,0.859,0.894)     RGB{N0f8}(0.58,0.796,0.776)
#  RGB{N0f8}(0.541,0.827,0.855)     RGB{N0f8}(0.573,0.776,0.761)
#  RGB{N0f8}(0.514,0.8,0.827)    …  RGB{N0f8}(0.553,0.749,0.737)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
