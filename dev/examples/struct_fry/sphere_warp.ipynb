# %% [markdown]
# # Cows are spherical

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sphere_warp(fabio)
save("assets/sphere_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.204,0.325,0.416)  …  RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.216,0.329,0.412)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.224,0.329,0.408)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.224,0.325,0.4)       RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.227,0.322,0.384)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.224,0.314,0.369)  …  RGB{N0f8}(0.129,0.184,0.22)
#  RGB{N0f8}(0.227,0.318,0.373)     RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.235,0.325,0.376)     RGB{N0f8}(0.122,0.176,0.212)
#  RGB{N0f8}(0.243,0.333,0.384)     RGB{N0f8}(0.122,0.176,0.212)
#  RGB{N0f8}(0.251,0.341,0.396)     RGB{N0f8}(0.122,0.176,0.212)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.91,0.78,0.639)       RGB{N0f8}(0.8,0.494,0.365)
#  RGB{N0f8}(0.902,0.78,0.624)      RGB{N0f8}(0.808,0.49,0.361)
#  RGB{N0f8}(0.89,0.78,0.635)       RGB{N0f8}(0.824,0.482,0.337)
#  RGB{N0f8}(0.878,0.761,0.655)  …  RGB{N0f8}(0.835,0.475,0.306)
#  RGB{N0f8}(0.835,0.71,0.616)      RGB{N0f8}(0.796,0.443,0.294)
#  RGB{N0f8}(0.812,0.702,0.569)     RGB{N0f8}(0.78,0.439,0.306)
#  RGB{N0f8}(0.796,0.698,0.529)     RGB{N0f8}(0.769,0.431,0.302)
#  RGB{N0f8}(0.776,0.682,0.49)      RGB{N0f8}(0.765,0.416,0.282)
#  RGB{N0f8}(0.757,0.655,0.455)  …  RGB{N0f8}(0.769,0.408,0.271)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
