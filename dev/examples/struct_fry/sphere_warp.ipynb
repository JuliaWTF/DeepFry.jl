# %% [markdown]
# # Cows are spherical

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sphere_warp(fabio)
save("assets/sphere_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.267,0.345,0.388)  …  RGB{N0f8}(0.133,0.173,0.212)
#  RGB{N0f8}(0.259,0.337,0.376)     RGB{N0f8}(0.133,0.173,0.212)
#  RGB{N0f8}(0.263,0.341,0.38)      RGB{N0f8}(0.129,0.176,0.216)
#  RGB{N0f8}(0.263,0.341,0.388)     RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.255,0.329,0.384)     RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.267,0.329,0.373)  …  RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.271,0.333,0.396)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.271,0.325,0.408)     RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.271,0.325,0.408)     RGB{N0f8}(0.125,0.176,0.216)
#  RGB{N0f8}(0.271,0.337,0.4)       RGB{N0f8}(0.122,0.173,0.212)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.675,0.533,0.361)     RGB{N0f8}(0.114,0.133,0.153)
#  RGB{N0f8}(0.643,0.482,0.349)     RGB{N0f8}(0.149,0.149,0.157)
#  RGB{N0f8}(0.631,0.431,0.306)     RGB{N0f8}(0.345,0.243,0.235)
#  RGB{N0f8}(0.667,0.482,0.302)  …  RGB{N0f8}(0.761,0.443,0.392)
#  RGB{N0f8}(0.694,0.541,0.353)     RGB{N0f8}(0.745,0.416,0.302)
#  RGB{N0f8}(0.686,0.537,0.318)     RGB{N0f8}(0.722,0.4,0.271)
#  RGB{N0f8}(0.694,0.533,0.325)     RGB{N0f8}(0.714,0.384,0.259)
#  RGB{N0f8}(0.722,0.549,0.353)     RGB{N0f8}(0.718,0.365,0.243)
#  RGB{N0f8}(0.745,0.573,0.345)  …  RGB{N0f8}(0.722,0.349,0.212)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
