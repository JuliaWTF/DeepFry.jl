# %% [markdown]
# # Cows are spherical

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sphere_warp(fabio)
save("assets/sphere_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.212,0.302,0.357)  …  RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.216,0.298,0.329)     RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.227,0.306,0.353)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.224,0.314,0.384)     RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.208,0.302,0.376)     RGB{N0f8}(0.122,0.173,0.208)
#  RGB{N0f8}(0.216,0.302,0.357)  …  RGB{N0f8}(0.122,0.173,0.204)
#  RGB{N0f8}(0.231,0.318,0.373)     RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.231,0.314,0.373)     RGB{N0f8}(0.129,0.18,0.216)
#  RGB{N0f8}(0.235,0.314,0.373)     RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.251,0.325,0.388)     RGB{N0f8}(0.125,0.18,0.216)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.745,0.612,0.475)     RGB{N0f8}(0.769,0.416,0.325)
#  RGB{N0f8}(0.737,0.616,0.451)     RGB{N0f8}(0.765,0.412,0.325)
#  RGB{N0f8}(0.725,0.616,0.431)     RGB{N0f8}(0.761,0.416,0.306)
#  RGB{N0f8}(0.733,0.631,0.431)  …  RGB{N0f8}(0.761,0.42,0.282)
#  RGB{N0f8}(0.753,0.655,0.455)     RGB{N0f8}(0.761,0.424,0.259)
#  RGB{N0f8}(0.796,0.698,0.502)     RGB{N0f8}(0.773,0.435,0.267)
#  RGB{N0f8}(0.816,0.714,0.561)     RGB{N0f8}(0.78,0.439,0.278)
#  RGB{N0f8}(0.816,0.714,0.6)       RGB{N0f8}(0.784,0.439,0.294)
#  RGB{N0f8}(0.808,0.706,0.604)  …  RGB{N0f8}(0.78,0.431,0.306)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
