# %% [markdown]
# # Laplace like bubble

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.laplace_warp(fabio)
save("assets/laplace_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.576,0.522,0.451)  …  RGB{N0f8}(0.145,0.2,0.235)
#  RGB{N0f8}(0.584,0.525,0.443)     RGB{N0f8}(0.145,0.2,0.235)
#  RGB{N0f8}(0.58,0.514,0.424)      RGB{N0f8}(0.141,0.196,0.231)
#  RGB{N0f8}(0.573,0.498,0.4)       RGB{N0f8}(0.141,0.196,0.231)
#  RGB{N0f8}(0.561,0.478,0.376)     RGB{N0f8}(0.137,0.192,0.227)
#  RGB{N0f8}(0.576,0.494,0.384)  …  RGB{N0f8}(0.137,0.192,0.227)
#  RGB{N0f8}(0.6,0.514,0.396)       RGB{N0f8}(0.133,0.188,0.224)
#  RGB{N0f8}(0.624,0.533,0.412)     RGB{N0f8}(0.133,0.188,0.224)
#  RGB{N0f8}(0.604,0.51,0.416)      RGB{N0f8}(0.133,0.188,0.224)
#  RGB{N0f8}(0.576,0.478,0.412)     RGB{N0f8}(0.133,0.188,0.224)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.208,0.243,0.271)     RGB{N0f8}(0.129,0.173,0.212)
#  RGB{N0f8}(0.208,0.239,0.271)     RGB{N0f8}(0.125,0.173,0.208)
#  RGB{N0f8}(0.204,0.239,0.271)     RGB{N0f8}(0.125,0.173,0.208)
#  RGB{N0f8}(0.2,0.235,0.271)    …  RGB{N0f8}(0.122,0.169,0.204)
#  RGB{N0f8}(0.196,0.235,0.267)     RGB{N0f8}(0.118,0.169,0.204)
#  RGB{N0f8}(0.188,0.227,0.263)     RGB{N0f8}(0.114,0.165,0.2)
#  RGB{N0f8}(0.18,0.224,0.259)      RGB{N0f8}(0.114,0.165,0.2)
#  RGB{N0f8}(0.176,0.216,0.255)     RGB{N0f8}(0.11,0.165,0.196)
#  RGB{N0f8}(0.169,0.212,0.251)  …  RGB{N0f8}(0.11,0.161,0.196)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
