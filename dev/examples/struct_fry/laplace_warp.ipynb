# %% [markdown]
# # Laplace like bubble

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.laplace_warp(fabio)
save("assets/laplace_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.435,0.357,0.306)  …  RGB{N0f8}(0.725,0.706,0.588)
#  RGB{N0f8}(0.435,0.361,0.314)     RGB{N0f8}(0.722,0.702,0.58)
#  RGB{N0f8}(0.439,0.361,0.322)     RGB{N0f8}(0.718,0.698,0.573)
#  RGB{N0f8}(0.443,0.361,0.329)     RGB{N0f8}(0.718,0.698,0.58)
#  RGB{N0f8}(0.447,0.365,0.337)     RGB{N0f8}(0.718,0.694,0.588)
#  RGB{N0f8}(0.439,0.365,0.329)  …  RGB{N0f8}(0.714,0.69,0.592)
#  RGB{N0f8}(0.424,0.361,0.302)     RGB{N0f8}(0.706,0.682,0.592)
#  RGB{N0f8}(0.431,0.365,0.302)     RGB{N0f8}(0.698,0.675,0.592)
#  RGB{N0f8}(0.439,0.369,0.31)      RGB{N0f8}(0.686,0.659,0.584)
#  RGB{N0f8}(0.451,0.369,0.314)     RGB{N0f8}(0.663,0.635,0.561)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.231,0.31,0.322)      RGB{N0f8}(0.125,0.129,0.169)
#  RGB{N0f8}(0.231,0.31,0.322)      RGB{N0f8}(0.118,0.129,0.165)
#  RGB{N0f8}(0.231,0.306,0.318)     RGB{N0f8}(0.106,0.133,0.165)
#  RGB{N0f8}(0.227,0.306,0.314)  …  RGB{N0f8}(0.094,0.137,0.173)
#  RGB{N0f8}(0.227,0.306,0.31)      RGB{N0f8}(0.086,0.145,0.176)
#  RGB{N0f8}(0.224,0.302,0.31)      RGB{N0f8}(0.078,0.149,0.184)
#  RGB{N0f8}(0.224,0.302,0.306)     RGB{N0f8}(0.082,0.153,0.192)
#  RGB{N0f8}(0.224,0.302,0.306)     RGB{N0f8}(0.09,0.153,0.192)
#  RGB{N0f8}(0.227,0.302,0.306)  …  RGB{N0f8}(0.102,0.145,0.188)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
