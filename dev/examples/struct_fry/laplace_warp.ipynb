# %% [markdown]
# # Laplace like bubble

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.laplace_warp(fabio)
save("assets/laplace_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.208,0.275,0.294)  …  RGB{N0f8}(1.0,0.788,0.667)
#  RGB{N0f8}(0.208,0.275,0.294)     RGB{N0f8}(1.0,0.784,0.659)
#  RGB{N0f8}(0.208,0.275,0.294)     RGB{N0f8}(1.0,0.784,0.655)
#  RGB{N0f8}(0.208,0.278,0.294)     RGB{N0f8}(1.0,0.784,0.651)
#  RGB{N0f8}(0.208,0.282,0.298)     RGB{N0f8}(1.0,0.788,0.647)
#  RGB{N0f8}(0.212,0.286,0.306)  …  RGB{N0f8}(1.0,0.792,0.651)
#  RGB{N0f8}(0.216,0.29,0.31)       RGB{N0f8}(1.0,0.792,0.655)
#  RGB{N0f8}(0.22,0.294,0.314)      RGB{N0f8}(1.0,0.788,0.659)
#  RGB{N0f8}(0.22,0.298,0.318)      RGB{N0f8}(0.996,0.773,0.651)
#  RGB{N0f8}(0.224,0.302,0.322)     RGB{N0f8}(0.996,0.761,0.647)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.733,0.659,0.604)     RGB{N0f8}(0.894,0.643,0.443)
#  RGB{N0f8}(0.765,0.694,0.62)      RGB{N0f8}(0.894,0.647,0.431)
#  RGB{N0f8}(0.792,0.722,0.635)     RGB{N0f8}(0.902,0.659,0.439)
#  RGB{N0f8}(0.82,0.753,0.647)   …  RGB{N0f8}(0.914,0.671,0.443)
#  RGB{N0f8}(0.847,0.776,0.663)     RGB{N0f8}(0.914,0.675,0.459)
#  RGB{N0f8}(0.871,0.796,0.682)     RGB{N0f8}(0.89,0.663,0.486)
#  RGB{N0f8}(0.89,0.816,0.702)      RGB{N0f8}(0.867,0.651,0.502)
#  RGB{N0f8}(0.91,0.827,0.722)      RGB{N0f8}(0.859,0.647,0.51)
#  RGB{N0f8}(0.925,0.835,0.741)  …  RGB{N0f8}(0.871,0.663,0.51)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
