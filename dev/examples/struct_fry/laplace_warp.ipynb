# %% [markdown]
# # Laplace like bubble

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.laplace_warp(fabio)
save("assets/laplace_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.843,0.494,0.337)  …  RGB{N0f8}(0.812,0.467,0.31)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.812,0.467,0.31)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.812,0.463,0.31)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.808,0.463,0.31)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.808,0.463,0.31)
#  RGB{N0f8}(0.843,0.494,0.337)  …  RGB{N0f8}(0.808,0.463,0.306)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.808,0.463,0.306)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.808,0.463,0.306)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.808,0.459,0.306)
#  RGB{N0f8}(0.843,0.494,0.337)     RGB{N0f8}(0.804,0.459,0.306)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.847,0.482,0.325)     RGB{N0f8}(0.675,0.361,0.286)
#  RGB{N0f8}(0.847,0.482,0.325)     RGB{N0f8}(0.69,0.361,0.278)
#  RGB{N0f8}(0.847,0.482,0.325)     RGB{N0f8}(0.698,0.361,0.271)
#  RGB{N0f8}(0.847,0.482,0.325)  …  RGB{N0f8}(0.733,0.38,0.267)
#  RGB{N0f8}(0.847,0.482,0.325)     RGB{N0f8}(0.765,0.404,0.271)
#  RGB{N0f8}(0.847,0.482,0.325)     RGB{N0f8}(0.792,0.431,0.278)
#  RGB{N0f8}(0.847,0.482,0.325)     RGB{N0f8}(0.8,0.443,0.294)
#  RGB{N0f8}(0.847,0.482,0.325)     RGB{N0f8}(0.808,0.451,0.31)
#  RGB{N0f8}(0.847,0.482,0.325)  …  RGB{N0f8}(0.816,0.459,0.322)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
