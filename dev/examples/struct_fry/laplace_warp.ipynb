# %% [markdown]
# # Laplace like bubble

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.laplace_warp(fabio)
save("assets/laplace_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.502,0.435)  …  RGB{N0f8}(0.596,0.404,0.247)
#  RGB{N0f8}(0.533,0.494,0.427)     RGB{N0f8}(0.604,0.412,0.259)
#  RGB{N0f8}(0.525,0.486,0.424)     RGB{N0f8}(0.612,0.427,0.275)
#  RGB{N0f8}(0.518,0.478,0.416)     RGB{N0f8}(0.62,0.439,0.286)
#  RGB{N0f8}(0.506,0.471,0.412)     RGB{N0f8}(0.631,0.455,0.302)
#  RGB{N0f8}(0.498,0.463,0.404)  …  RGB{N0f8}(0.639,0.467,0.318)
#  RGB{N0f8}(0.49,0.455,0.396)      RGB{N0f8}(0.647,0.482,0.329)
#  RGB{N0f8}(0.482,0.451,0.392)     RGB{N0f8}(0.655,0.494,0.345)
#  RGB{N0f8}(0.478,0.443,0.388)     RGB{N0f8}(0.663,0.506,0.357)
#  RGB{N0f8}(0.475,0.439,0.38)      RGB{N0f8}(0.671,0.522,0.373)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.6,0.518,0.416)       RGB{N0f8}(0.125,0.18,0.192)
#  RGB{N0f8}(0.518,0.443,0.353)     RGB{N0f8}(0.122,0.176,0.184)
#  RGB{N0f8}(0.518,0.443,0.365)     RGB{N0f8}(0.122,0.176,0.188)
#  RGB{N0f8}(0.58,0.502,0.435)   …  RGB{N0f8}(0.125,0.18,0.188)
#  RGB{N0f8}(0.635,0.529,0.447)     RGB{N0f8}(0.125,0.184,0.192)
#  RGB{N0f8}(0.69,0.588,0.486)      RGB{N0f8}(0.125,0.188,0.192)
#  RGB{N0f8}(0.745,0.651,0.537)     RGB{N0f8}(0.129,0.188,0.196)
#  RGB{N0f8}(0.788,0.698,0.58)      RGB{N0f8}(0.129,0.192,0.196)
#  RGB{N0f8}(0.769,0.682,0.588)  …  RGB{N0f8}(0.133,0.196,0.2)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
