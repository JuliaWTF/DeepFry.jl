# %% [markdown]
# # Bubble like Gauss

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_warp(fabio)
save("assets/gauss_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.427,0.365,0.369)  …  RGB{N0f8}(0.149,0.2,0.235)
#  RGB{N0f8}(0.439,0.337,0.31)      RGB{N0f8}(0.145,0.196,0.231)
#  RGB{N0f8}(0.451,0.345,0.31)      RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.424,0.341,0.318)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.404,0.345,0.337)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.404,0.345,0.322)  …  RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.424,0.345,0.306)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.412,0.341,0.314)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.412,0.345,0.322)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.42,0.353,0.318)      RGB{N0f8}(0.133,0.184,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.733,0.631,0.514)     RGB{N0f8}(0.78,0.435,0.298)
#  RGB{N0f8}(0.686,0.58,0.506)      RGB{N0f8}(0.812,0.451,0.314)
#  RGB{N0f8}(0.659,0.549,0.502)     RGB{N0f8}(0.835,0.463,0.337)
#  RGB{N0f8}(0.718,0.608,0.561)  …  RGB{N0f8}(0.839,0.482,0.4)
#  RGB{N0f8}(0.8,0.69,0.62)         RGB{N0f8}(0.851,0.514,0.475)
#  RGB{N0f8}(0.796,0.694,0.588)     RGB{N0f8}(0.863,0.525,0.467)
#  RGB{N0f8}(0.827,0.725,0.596)     RGB{N0f8}(0.871,0.537,0.447)
#  RGB{N0f8}(0.859,0.753,0.671)     RGB{N0f8}(0.886,0.557,0.439)
#  RGB{N0f8}(0.816,0.714,0.58)   …  RGB{N0f8}(0.894,0.565,0.427)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
