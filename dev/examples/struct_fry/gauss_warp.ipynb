# %% [markdown]
# # Bubble like Gauss

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_warp(fabio)
save("assets/gauss_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.341,0.302,0.267)  …  RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)  …  RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.341,0.302,0.267)     RGB{N0f8}(0.341,0.302,0.267)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.302,0.224,0.208)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.282,0.216,0.204)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.255,0.2,0.192)       RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.263,0.212,0.208)  …  RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.306,0.247,0.239)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.349,0.282,0.271)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.388,0.318,0.302)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.427,0.349,0.329)     RGB{N0f8}(0.341,0.302,0.267)
#  RGB{N0f8}(0.459,0.369,0.341)  …  RGB{N0f8}(0.341,0.302,0.267)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
