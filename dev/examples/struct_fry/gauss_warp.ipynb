# %% [markdown]
# # Bubble like Gauss

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_warp(fabio)
save("assets/gauss_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.427,0.349,0.353)  …  RGB{N0f8}(0.145,0.196,0.231)
#  RGB{N0f8}(0.447,0.333,0.306)     RGB{N0f8}(0.145,0.196,0.231)
#  RGB{N0f8}(0.451,0.345,0.31)      RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.412,0.337,0.322)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.396,0.353,0.345)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.408,0.349,0.325)  …  RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.427,0.349,0.31)      RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.416,0.353,0.329)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.416,0.357,0.329)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.427,0.361,0.325)     RGB{N0f8}(0.133,0.184,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.827,0.718,0.624)     RGB{N0f8}(0.773,0.416,0.275)
#  RGB{N0f8}(0.737,0.627,0.569)     RGB{N0f8}(0.796,0.431,0.286)
#  RGB{N0f8}(0.639,0.525,0.502)     RGB{N0f8}(0.82,0.451,0.318)
#  RGB{N0f8}(0.608,0.498,0.478)  …  RGB{N0f8}(0.839,0.471,0.353)
#  RGB{N0f8}(0.678,0.573,0.533)     RGB{N0f8}(0.843,0.486,0.384)
#  RGB{N0f8}(0.741,0.647,0.576)     RGB{N0f8}(0.839,0.518,0.424)
#  RGB{N0f8}(0.745,0.655,0.561)     RGB{N0f8}(0.843,0.522,0.424)
#  RGB{N0f8}(0.816,0.706,0.639)     RGB{N0f8}(0.851,0.525,0.424)
#  RGB{N0f8}(0.82,0.714,0.612)   …  RGB{N0f8}(0.871,0.541,0.439)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
