# %% [markdown]
# # Bubble like Gauss

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_warp(fabio)
save("assets/gauss_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.408,0.333,0.31)   …  RGB{N0f8}(0.522,0.443,0.349)
#  RGB{N0f8}(0.416,0.337,0.306)     RGB{N0f8}(0.533,0.424,0.325)
#  RGB{N0f8}(0.42,0.341,0.298)      RGB{N0f8}(0.553,0.412,0.31)
#  RGB{N0f8}(0.42,0.341,0.286)      RGB{N0f8}(0.525,0.412,0.325)
#  RGB{N0f8}(0.416,0.341,0.286)     RGB{N0f8}(0.498,0.416,0.341)
#  RGB{N0f8}(0.424,0.337,0.294)  …  RGB{N0f8}(0.478,0.408,0.341)
#  RGB{N0f8}(0.427,0.337,0.302)     RGB{N0f8}(0.447,0.376,0.298)
#  RGB{N0f8}(0.427,0.337,0.31)      RGB{N0f8}(0.404,0.341,0.247)
#  RGB{N0f8}(0.431,0.341,0.318)     RGB{N0f8}(0.4,0.337,0.235)
#  RGB{N0f8}(0.431,0.357,0.314)     RGB{N0f8}(0.404,0.349,0.235)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.639,0.549,0.451)     RGB{N0f8}(0.906,0.584,0.357)
#  RGB{N0f8}(0.675,0.596,0.494)     RGB{N0f8}(0.906,0.58,0.369)
#  RGB{N0f8}(0.714,0.643,0.541)     RGB{N0f8}(0.902,0.58,0.373)
#  RGB{N0f8}(0.753,0.686,0.592)  …  RGB{N0f8}(0.902,0.58,0.376)
#  RGB{N0f8}(0.784,0.722,0.643)     RGB{N0f8}(0.902,0.58,0.384)
#  RGB{N0f8}(0.788,0.714,0.635)     RGB{N0f8}(0.902,0.58,0.376)
#  RGB{N0f8}(0.78,0.702,0.627)      RGB{N0f8}(0.898,0.58,0.373)
#  RGB{N0f8}(0.769,0.69,0.604)      RGB{N0f8}(0.898,0.58,0.369)
#  RGB{N0f8}(0.753,0.675,0.584)  …  RGB{N0f8}(0.894,0.576,0.357)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
