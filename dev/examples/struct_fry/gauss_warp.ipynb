# %% [markdown]
# # Bubble like Gauss

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_warp(fabio)
save("assets/gauss_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.192,0.224,0.243)  …  RGB{N0f8}(0.125,0.165,0.2)
#  RGB{N0f8}(0.196,0.224,0.247)     RGB{N0f8}(0.125,0.165,0.2)
#  RGB{N0f8}(0.204,0.227,0.251)     RGB{N0f8}(0.129,0.169,0.204)
#  RGB{N0f8}(0.212,0.231,0.255)     RGB{N0f8}(0.129,0.169,0.204)
#  RGB{N0f8}(0.22,0.235,0.259)      RGB{N0f8}(0.129,0.169,0.204)
#  RGB{N0f8}(0.224,0.239,0.267)  …  RGB{N0f8}(0.129,0.169,0.204)
#  RGB{N0f8}(0.231,0.243,0.271)     RGB{N0f8}(0.133,0.173,0.208)
#  RGB{N0f8}(0.239,0.247,0.275)     RGB{N0f8}(0.133,0.173,0.208)
#  RGB{N0f8}(0.247,0.251,0.278)     RGB{N0f8}(0.133,0.173,0.208)
#  RGB{N0f8}(0.251,0.251,0.282)     RGB{N0f8}(0.133,0.173,0.208)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.204,0.231,0.263)     RGB{N0f8}(0.275,0.267,0.267)
#  RGB{N0f8}(0.204,0.231,0.263)     RGB{N0f8}(0.255,0.251,0.251)
#  RGB{N0f8}(0.2,0.227,0.259)       RGB{N0f8}(0.239,0.235,0.239)
#  RGB{N0f8}(0.196,0.227,0.259)  …  RGB{N0f8}(0.224,0.224,0.231)
#  RGB{N0f8}(0.196,0.224,0.255)     RGB{N0f8}(0.208,0.212,0.22)
#  RGB{N0f8}(0.192,0.224,0.255)     RGB{N0f8}(0.192,0.2,0.208)
#  RGB{N0f8}(0.188,0.22,0.251)      RGB{N0f8}(0.192,0.204,0.212)
#  RGB{N0f8}(0.188,0.22,0.251)      RGB{N0f8}(0.196,0.212,0.224)
#  RGB{N0f8}(0.184,0.216,0.247)  …  RGB{N0f8}(0.2,0.22,0.231)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
