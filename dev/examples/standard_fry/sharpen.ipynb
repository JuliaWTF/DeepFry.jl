# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.294,0.275,0.278)  …  RGB{N0f8}(0.078,0.106,0.125)
#  RGB{N0f8}(0.294,0.275,0.278)     RGB{N0f8}(0.078,0.106,0.125)
#  RGB{N0f8}(0.31,0.31,0.314)       RGB{N0f8}(0.078,0.106,0.125)
#  RGB{N0f8}(0.224,0.149,0.145)     RGB{N0f8}(0.075,0.102,0.122)
#  RGB{N0f8}(0.298,0.184,0.169)     RGB{N0f8}(0.075,0.102,0.122)
#  RGB{N0f8}(0.239,0.184,0.141)  …  RGB{N0f8}(0.071,0.098,0.118)
#  RGB{N0f8}(0.227,0.192,0.165)     RGB{N0f8}(0.067,0.094,0.114)
#  RGB{N0f8}(0.255,0.188,0.188)     RGB{N0f8}(0.071,0.098,0.118)
#  RGB{N0f8}(0.271,0.188,0.18)      RGB{N0f8}(0.075,0.102,0.122)
#  RGB{N0f8}(0.247,0.192,0.141)     RGB{N0f8}(0.078,0.106,0.125)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.51,0.455,0.404)      RGB{N0f8}(0.447,0.243,0.165)
#  RGB{N0f8}(0.486,0.427,0.38)      RGB{N0f8}(0.455,0.255,0.192)
#  RGB{N0f8}(0.514,0.424,0.384)     RGB{N0f8}(0.447,0.247,0.196)
#  RGB{N0f8}(0.314,0.337,0.282)  …  RGB{N0f8}(0.451,0.29,0.224)
#  RGB{N0f8}(0.247,0.224,0.239)     RGB{N0f8}(0.451,0.282,0.216)
#  RGB{N0f8}(0.239,0.212,0.208)     RGB{N0f8}(0.455,0.275,0.216)
#  RGB{N0f8}(0.329,0.302,0.212)     RGB{N0f8}(0.471,0.294,0.239)
#  RGB{N0f8}(0.298,0.263,0.173)     RGB{N0f8}(0.471,0.286,0.239)
#  RGB{N0f8}(0.357,0.306,0.286)  …  RGB{N0f8}(0.49,0.306,0.259)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
