# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.502,0.467,0.471)  …  RGB{N0f8}(0.133,0.18,0.212)
#  RGB{N0f8}(0.502,0.467,0.471)     RGB{N0f8}(0.133,0.18,0.212)
#  RGB{N0f8}(0.529,0.525,0.533)     RGB{N0f8}(0.133,0.18,0.216)
#  RGB{N0f8}(0.376,0.251,0.243)     RGB{N0f8}(0.129,0.176,0.208)
#  RGB{N0f8}(0.51,0.318,0.286)      RGB{N0f8}(0.125,0.173,0.204)
#  RGB{N0f8}(0.408,0.314,0.239)  …  RGB{N0f8}(0.122,0.169,0.2)
#  RGB{N0f8}(0.384,0.325,0.282)     RGB{N0f8}(0.114,0.161,0.196)
#  RGB{N0f8}(0.435,0.318,0.322)     RGB{N0f8}(0.122,0.169,0.2)
#  RGB{N0f8}(0.463,0.318,0.306)     RGB{N0f8}(0.125,0.173,0.204)
#  RGB{N0f8}(0.42,0.329,0.243)      RGB{N0f8}(0.133,0.18,0.212)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.867,0.776,0.686)     RGB{N0f8}(0.757,0.416,0.282)
#  RGB{N0f8}(0.827,0.725,0.647)     RGB{N0f8}(0.773,0.435,0.325)
#  RGB{N0f8}(0.878,0.722,0.651)     RGB{N0f8}(0.761,0.424,0.337)
#  RGB{N0f8}(0.537,0.573,0.482)  …  RGB{N0f8}(0.773,0.494,0.38)
#  RGB{N0f8}(0.424,0.38,0.404)      RGB{N0f8}(0.765,0.478,0.369)
#  RGB{N0f8}(0.408,0.357,0.357)     RGB{N0f8}(0.773,0.467,0.365)
#  RGB{N0f8}(0.561,0.518,0.361)     RGB{N0f8}(0.8,0.498,0.408)
#  RGB{N0f8}(0.506,0.451,0.29)      RGB{N0f8}(0.804,0.49,0.408)
#  RGB{N0f8}(0.608,0.522,0.486)  …  RGB{N0f8}(0.831,0.522,0.443)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
