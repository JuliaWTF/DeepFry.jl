# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.039,0.035,0.035)  …  RGB{N0f8}(0.012,0.016,0.016)
#  RGB{N0f8}(0.039,0.035,0.035)     RGB{N0f8}(0.012,0.016,0.016)
#  RGB{N0f8}(0.039,0.039,0.039)     RGB{N0f8}(0.012,0.016,0.016)
#  RGB{N0f8}(0.027,0.02,0.02)       RGB{N0f8}(0.012,0.012,0.016)
#  RGB{N0f8}(0.039,0.024,0.024)     RGB{N0f8}(0.008,0.012,0.016)
#  RGB{N0f8}(0.031,0.024,0.02)   …  RGB{N0f8}(0.008,0.012,0.016)
#  RGB{N0f8}(0.027,0.024,0.024)     RGB{N0f8}(0.008,0.012,0.016)
#  RGB{N0f8}(0.035,0.024,0.024)     RGB{N0f8}(0.008,0.012,0.016)
#  RGB{N0f8}(0.035,0.024,0.024)     RGB{N0f8}(0.008,0.012,0.016)
#  RGB{N0f8}(0.031,0.024,0.02)      RGB{N0f8}(0.012,0.016,0.016)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.067,0.059,0.051)     RGB{N0f8}(0.059,0.031,0.02)
#  RGB{N0f8}(0.063,0.055,0.051)     RGB{N0f8}(0.059,0.031,0.024)
#  RGB{N0f8}(0.067,0.055,0.051)     RGB{N0f8}(0.059,0.031,0.027)
#  RGB{N0f8}(0.039,0.043,0.035)  …  RGB{N0f8}(0.059,0.039,0.027)
#  RGB{N0f8}(0.031,0.027,0.031)     RGB{N0f8}(0.059,0.035,0.027)
#  RGB{N0f8}(0.031,0.027,0.027)     RGB{N0f8}(0.059,0.035,0.027)
#  RGB{N0f8}(0.043,0.039,0.027)     RGB{N0f8}(0.063,0.039,0.031)
#  RGB{N0f8}(0.039,0.035,0.024)     RGB{N0f8}(0.063,0.039,0.031)
#  RGB{N0f8}(0.047,0.039,0.035)  …  RGB{N0f8}(0.063,0.039,0.035)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
