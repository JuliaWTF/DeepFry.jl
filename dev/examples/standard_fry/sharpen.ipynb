# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(1.0,1.0,1.0)      …  RGB{N0f8}(0.455,0.616,0.729)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(0.455,0.616,0.729)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(0.459,0.624,0.733)
#  RGB{N0f8}(1.0,0.863,0.835)     RGB{N0f8}(0.443,0.604,0.718)
#  RGB{N0f8}(1.0,1.0,0.98)        RGB{N0f8}(0.431,0.592,0.706)
#  RGB{N0f8}(1.0,1.0,0.816)    …  RGB{N0f8}(0.42,0.58,0.69)
#  RGB{N0f8}(1.0,1.0,0.969)       RGB{N0f8}(0.396,0.557,0.671)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(0.416,0.576,0.69)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(0.431,0.592,0.706)
#  RGB{N0f8}(1.0,1.0,0.831)       RGB{N0f8}(0.459,0.62,0.733)
#  ⋮                           ⋱  ⋮
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,0.969)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)      …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)      …  RGB{N0f8}(1.0,1.0,1.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
