# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(0.322,0.439,0.518)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(0.322,0.439,0.518)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(0.325,0.439,0.522)
#  RGB{N0f8}(0.918,0.612,0.592)     RGB{N0f8}(0.314,0.427,0.51)
#  RGB{N0f8}(1.0,0.773,0.694)       RGB{N0f8}(0.306,0.42,0.502)
#  RGB{N0f8}(0.992,0.761,0.58)   …  RGB{N0f8}(0.298,0.412,0.49)
#  RGB{N0f8}(0.937,0.796,0.686)     RGB{N0f8}(0.282,0.396,0.475)
#  RGB{N0f8}(1.0,0.773,0.784)       RGB{N0f8}(0.294,0.412,0.49)
#  RGB{N0f8}(1.0,0.773,0.745)       RGB{N0f8}(0.306,0.42,0.498)
#  RGB{N0f8}(1.0,0.8,0.588)         RGB{N0f8}(0.325,0.439,0.518)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,0.686)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,0.792)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,0.816)
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(1.0,1.0,0.929)
#  RGB{N0f8}(1.0,0.925,0.984)       RGB{N0f8}(1.0,1.0,0.894)
#  RGB{N0f8}(0.996,0.871,0.867)     RGB{N0f8}(1.0,1.0,0.89)
#  RGB{N0f8}(1.0,1.0,0.878)         RGB{N0f8}(1.0,1.0,0.996)
#  RGB{N0f8}(1.0,1.0,0.71)          RGB{N0f8}(1.0,1.0,0.996)
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(1.0,1.0,1.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
