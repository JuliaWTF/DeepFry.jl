# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.506,0.475,0.478)  …  RGB{N0f8}(0.133,0.184,0.216)
#  RGB{N0f8}(0.506,0.475,0.478)     RGB{N0f8}(0.133,0.184,0.216)
#  RGB{N0f8}(0.537,0.533,0.541)     RGB{N0f8}(0.137,0.184,0.216)
#  RGB{N0f8}(0.384,0.255,0.247)     RGB{N0f8}(0.129,0.18,0.212)
#  RGB{N0f8}(0.514,0.322,0.29)      RGB{N0f8}(0.129,0.176,0.208)
#  RGB{N0f8}(0.416,0.318,0.243)  …  RGB{N0f8}(0.125,0.173,0.204)
#  RGB{N0f8}(0.392,0.333,0.286)     RGB{N0f8}(0.118,0.165,0.2)
#  RGB{N0f8}(0.443,0.322,0.325)     RGB{N0f8}(0.122,0.173,0.204)
#  RGB{N0f8}(0.467,0.322,0.31)      RGB{N0f8}(0.125,0.176,0.208)
#  RGB{N0f8}(0.424,0.333,0.247)     RGB{N0f8}(0.137,0.184,0.216)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.882,0.788,0.694)     RGB{N0f8}(0.769,0.424,0.286)
#  RGB{N0f8}(0.839,0.737,0.655)     RGB{N0f8}(0.784,0.443,0.329)
#  RGB{N0f8}(0.89,0.733,0.663)      RGB{N0f8}(0.773,0.431,0.341)
#  RGB{N0f8}(0.545,0.58,0.49)    …  RGB{N0f8}(0.78,0.502,0.388)
#  RGB{N0f8}(0.427,0.384,0.412)     RGB{N0f8}(0.776,0.486,0.373)
#  RGB{N0f8}(0.416,0.365,0.361)     RGB{N0f8}(0.784,0.475,0.369)
#  RGB{N0f8}(0.569,0.525,0.365)     RGB{N0f8}(0.812,0.506,0.416)
#  RGB{N0f8}(0.514,0.459,0.294)     RGB{N0f8}(0.816,0.498,0.416)
#  RGB{N0f8}(0.616,0.529,0.49)   …  RGB{N0f8}(0.843,0.529,0.451)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
