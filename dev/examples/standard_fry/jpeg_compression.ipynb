# %% [markdown]
# # jpeg_compression

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.jpeg_compression(fabio)
save("assets/jpeg_compression.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.584,0.439,0.404)  …  RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.525,0.38,0.345)      RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.467,0.322,0.286)     RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.451,0.306,0.271)     RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.478,0.333,0.298)     RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.502,0.357,0.322)  …  RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.49,0.345,0.31)       RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.471,0.325,0.29)      RGB{N0f8}(0.153,0.208,0.251)
#  RGB{N0f8}(0.467,0.322,0.286)     RGB{N0f8}(0.125,0.18,0.224)
#  RGB{N0f8}(0.467,0.322,0.286)     RGB{N0f8}(0.125,0.18,0.224)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.847,0.737,0.682)     RGB{N0f8}(0.812,0.471,0.353)
#  RGB{N0f8}(0.529,0.42,0.365)      RGB{N0f8}(0.863,0.522,0.404)
#  RGB{N0f8}(0.522,0.412,0.357)     RGB{N0f8}(0.867,0.525,0.408)
#  RGB{N0f8}(0.522,0.412,0.357)  …  RGB{N0f8}(0.875,0.533,0.416)
#  RGB{N0f8}(0.545,0.435,0.38)      RGB{N0f8}(0.886,0.545,0.427)
#  RGB{N0f8}(0.6,0.49,0.435)        RGB{N0f8}(0.898,0.557,0.439)
#  RGB{N0f8}(0.682,0.573,0.518)     RGB{N0f8}(0.91,0.569,0.451)
#  RGB{N0f8}(0.761,0.651,0.596)     RGB{N0f8}(0.918,0.576,0.459)
#  RGB{N0f8}(0.808,0.698,0.643)  …  RGB{N0f8}(0.922,0.58,0.463)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
