# %% [markdown]
# # add_noise

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.add_noise(fabio)
save("assets/add_noise.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.506,0.51)   …  RGB{N0f8}(0.149,0.2,0.235)
#  RGB{N0f8}(0.102,0.102,0.133)     RGB{N0f8}(0.145,0.196,0.231)
#  RGB{N0f8}(0.267,0.09,0.267)      RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.392,0.231,0.071)     RGB{N0f8}(0.035,0.184,0.125)
#  RGB{N0f8}(0.435,0.349,0.306)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.055,0.118,0.078)  …  RGB{N0f8}(0.106,0.063,0.145)
#  RGB{N0f8}(0.447,0.322,0.141)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.451,0.153,0.059)     RGB{N0f8}(0.086,0.184,0.02)
#  RGB{N0f8}(0.431,0.337,0.298)     RGB{N0f8}(0.122,0.067,0.129)
#  RGB{N0f8}(0.435,0.341,0.302)     RGB{N0f8}(0.082,0.035,0.02)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.851,0.341,0.106)     RGB{N0f8}(0.675,0.165,0.039)
#  RGB{N0f8}(0.388,0.365,0.196)     RGB{N0f8}(0.851,0.51,0.482)
#  RGB{N0f8}(0.498,0.459,0.451)     RGB{N0f8}(0.871,0.529,0.49)
#  RGB{N0f8}(0.392,0.169,0.047)  …  RGB{N0f8}(0.871,0.537,0.455)
#  RGB{N0f8}(0.573,0.522,0.388)     RGB{N0f8}(0.6,0.482,0.106)
#  RGB{N0f8}(0.576,0.514,0.373)     RGB{N0f8}(0.898,0.569,0.424)
#  RGB{N0f8}(0.659,0.576,0.51)      RGB{N0f8}(0.165,0.008,0.027)
#  RGB{N0f8}(0.137,0.376,0.173)     RGB{N0f8}(0.925,0.596,0.424)
#  RGB{N0f8}(0.165,0.098,0.027)  …  RGB{N0f8}(0.878,0.243,0.047)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
