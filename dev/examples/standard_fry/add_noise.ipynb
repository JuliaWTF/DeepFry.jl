# %% [markdown]
# # add_noise

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.add_noise(fabio)
save("assets/add_noise.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.506,0.51)   …  RGB{N0f8}(0.129,0.145,0.008)
#  RGB{N0f8}(0.459,0.337,0.325)     RGB{N0f8}(0.145,0.196,0.231)
#  RGB{N0f8}(0.51,0.341,0.306)      RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.043,0.012,0.184)     RGB{N0f8}(0.125,0.004,0.051)
#  RGB{N0f8}(0.329,0.255,0.286)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.467,0.345,0.333)  …  RGB{N0f8}(0.043,0.173,0.039)
#  RGB{N0f8}(0.482,0.345,0.322)     RGB{N0f8}(0.02,0.161,0.153)
#  RGB{N0f8}(0.455,0.349,0.282)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.357,0.106,0.027)     RGB{N0f8}(0.122,0.157,0.082)
#  RGB{N0f8}(0.435,0.341,0.302)     RGB{N0f8}(0.133,0.184,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.867,0.745,0.667)     RGB{N0f8}(0.784,0.227,0.255)
#  RGB{N0f8}(0.624,0.612,0.537)     RGB{N0f8}(0.851,0.51,0.482)
#  RGB{N0f8}(0.498,0.459,0.451)     RGB{N0f8}(0.871,0.529,0.49)
#  RGB{N0f8}(0.482,0.431,0.4)    …  RGB{N0f8}(0.706,0.173,0.357)
#  RGB{N0f8}(0.322,0.086,0.212)     RGB{N0f8}(0.165,0.329,0.263)
#  RGB{N0f8}(0.576,0.514,0.373)     RGB{N0f8}(0.58,0.271,0.318)
#  RGB{N0f8}(0.659,0.576,0.51)      RGB{N0f8}(0.702,0.224,0.02)
#  RGB{N0f8}(0.749,0.675,0.608)     RGB{N0f8}(0.4,0.494,0.075)
#  RGB{N0f8}(0.663,0.6,0.459)    …  RGB{N0f8}(0.522,0.216,0.216)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
