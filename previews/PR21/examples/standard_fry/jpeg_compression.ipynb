# %% [markdown]
# # jpeg_compression

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.jpeg_compression(fabio)
save("assets/jpeg_compression.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.553,0.42,0.384)   …  RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.498,0.365,0.329)     RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.439,0.306,0.271)     RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.427,0.294,0.259)     RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.451,0.318,0.282)     RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.475,0.341,0.306)  …  RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.467,0.333,0.298)     RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.447,0.314,0.278)     RGB{N0f8}(0.153,0.204,0.239)
#  RGB{N0f8}(0.471,0.337,0.302)     RGB{N0f8}(0.125,0.176,0.212)
#  RGB{N0f8}(0.471,0.337,0.302)     RGB{N0f8}(0.125,0.176,0.212)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.796,0.776,0.698)     RGB{N0f8}(0.859,0.482,0.388)
#  RGB{N0f8}(0.553,0.533,0.455)     RGB{N0f8}(0.878,0.502,0.408)
#  RGB{N0f8}(0.478,0.459,0.38)      RGB{N0f8}(0.882,0.506,0.412)
#  RGB{N0f8}(0.427,0.408,0.329)  …  RGB{N0f8}(0.89,0.514,0.42)
#  RGB{N0f8}(0.478,0.459,0.38)      RGB{N0f8}(0.902,0.525,0.431)
#  RGB{N0f8}(0.604,0.584,0.506)     RGB{N0f8}(0.914,0.537,0.443)
#  RGB{N0f8}(0.706,0.686,0.608)     RGB{N0f8}(0.922,0.545,0.451)
#  RGB{N0f8}(0.725,0.706,0.627)     RGB{N0f8}(0.929,0.553,0.459)
#  RGB{N0f8}(0.706,0.686,0.608)  …  RGB{N0f8}(0.933,0.557,0.463)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
