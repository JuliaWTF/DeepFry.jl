# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.62,0.58,0.584)    …  RGB{N0f8}(0.165,0.224,0.263)
#  RGB{N0f8}(0.62,0.58,0.584)       RGB{N0f8}(0.165,0.224,0.263)
#  RGB{N0f8}(0.655,0.651,0.663)     RGB{N0f8}(0.165,0.224,0.267)
#  RGB{N0f8}(0.467,0.314,0.302)     RGB{N0f8}(0.161,0.22,0.259)
#  RGB{N0f8}(0.627,0.392,0.353)     RGB{N0f8}(0.157,0.216,0.255)
#  RGB{N0f8}(0.506,0.388,0.294)  …  RGB{N0f8}(0.149,0.208,0.251)
#  RGB{N0f8}(0.475,0.404,0.349)     RGB{N0f8}(0.141,0.2,0.243)
#  RGB{N0f8}(0.541,0.392,0.4)       RGB{N0f8}(0.149,0.208,0.251)
#  RGB{N0f8}(0.573,0.392,0.38)      RGB{N0f8}(0.157,0.216,0.255)
#  RGB{N0f8}(0.518,0.408,0.298)     RGB{N0f8}(0.165,0.224,0.263)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(1.0,0.961,0.847)       RGB{N0f8}(0.937,0.514,0.349)
#  RGB{N0f8}(1.0,0.898,0.8)         RGB{N0f8}(0.957,0.537,0.404)
#  RGB{N0f8}(1.0,0.894,0.808)       RGB{N0f8}(0.941,0.525,0.416)
#  RGB{N0f8}(0.663,0.71,0.596)   …  RGB{N0f8}(0.953,0.616,0.471)
#  RGB{N0f8}(0.522,0.471,0.502)     RGB{N0f8}(0.949,0.596,0.455)
#  RGB{N0f8}(0.506,0.443,0.439)     RGB{N0f8}(0.957,0.576,0.451)
#  RGB{N0f8}(0.694,0.639,0.447)     RGB{N0f8}(0.992,0.616,0.506)
#  RGB{N0f8}(0.627,0.557,0.361)     RGB{N0f8}(0.996,0.608,0.506)
#  RGB{N0f8}(0.749,0.643,0.6)    …  RGB{N0f8}(1.0,0.647,0.549)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
