# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(1.0,1.0,1.0)      …  RGB{N0f8}(0.369,0.502,0.592)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(0.369,0.502,0.592)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(0.373,0.506,0.596)
#  RGB{N0f8}(1.0,0.702,0.678)     RGB{N0f8}(0.361,0.49,0.584)
#  RGB{N0f8}(1.0,0.882,0.796)     RGB{N0f8}(0.353,0.482,0.573)
#  RGB{N0f8}(1.0,0.871,0.667)  …  RGB{N0f8}(0.341,0.471,0.561)
#  RGB{N0f8}(1.0,0.91,0.788)      RGB{N0f8}(0.322,0.455,0.545)
#  RGB{N0f8}(1.0,0.886,0.898)     RGB{N0f8}(0.337,0.471,0.561)
#  RGB{N0f8}(1.0,0.886,0.855)     RGB{N0f8}(0.349,0.482,0.573)
#  RGB{N0f8}(1.0,0.914,0.675)     RGB{N0f8}(0.373,0.506,0.596)
#  ⋮                           ⋱  ⋮
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,0.788)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,0.906)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,0.937)
#  RGB{N0f8}(1.0,1.0,1.0)      …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,0.992)       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)         RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,0.812)       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)      …  RGB{N0f8}(1.0,1.0,1.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
