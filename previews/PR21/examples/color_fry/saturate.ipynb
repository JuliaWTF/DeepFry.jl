# %% [markdown]
# # It's saturated

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.saturate(fabio)
save("assets/saturate.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.541,0.043,0.098)  …  RGB{N0f8}(0.02,0.145,0.235)
#  RGB{N0f8}(0.459,0.075,0.035)     RGB{N0f8}(0.02,0.145,0.231)
#  RGB{N0f8}(0.51,0.122,0.039)      RGB{N0f8}(0.02,0.141,0.227)
#  RGB{N0f8}(0.455,0.184,0.035)     RGB{N0f8}(0.02,0.141,0.227)
#  RGB{N0f8}(0.435,0.169,0.035)     RGB{N0f8}(0.02,0.141,0.224)
#  RGB{N0f8}(0.467,0.075,0.035)  …  RGB{N0f8}(0.02,0.141,0.224)
#  RGB{N0f8}(0.482,0.102,0.039)     RGB{N0f8}(0.02,0.141,0.227)
#  RGB{N0f8}(0.455,0.196,0.035)     RGB{N0f8}(0.02,0.141,0.227)
#  RGB{N0f8}(0.431,0.153,0.035)     RGB{N0f8}(0.02,0.141,0.224)
#  RGB{N0f8}(0.435,0.153,0.035)     RGB{N0f8}(0.016,0.137,0.22)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.867,0.38,0.071)      RGB{N0f8}(0.831,0.259,0.067)
#  RGB{N0f8}(0.624,0.545,0.051)     RGB{N0f8}(0.851,0.125,0.067)
#  RGB{N0f8}(0.498,0.118,0.039)     RGB{N0f8}(0.871,0.153,0.071)
#  RGB{N0f8}(0.482,0.208,0.039)  …  RGB{N0f8}(0.871,0.227,0.071)
#  RGB{N0f8}(0.573,0.427,0.047)     RGB{N0f8}(0.89,0.278,0.071)
#  RGB{N0f8}(0.576,0.412,0.047)     RGB{N0f8}(0.898,0.325,0.071)
#  RGB{N0f8}(0.659,0.325,0.051)     RGB{N0f8}(0.906,0.353,0.071)
#  RGB{N0f8}(0.749,0.384,0.059)     RGB{N0f8}(0.925,0.365,0.075)
#  RGB{N0f8}(0.663,0.475,0.051)  …  RGB{N0f8}(0.89,0.353,0.071)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
