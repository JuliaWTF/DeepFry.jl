# %% [markdown]
# # D-D-D-D-Dither

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.bayer_dither(fabio)
save("assets/bayer_dither.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(0.0,0.0,0.0)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(0.0,0.0,0.0)
#  ⋮                                               ⋱  ⋮
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,0.0)     RGB{N0f8}(1.0,1.0,0.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(0.0,0.0,0.0)  …  RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,0.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,0.0,0.0)     RGB{N0f8}(1.0,1.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
