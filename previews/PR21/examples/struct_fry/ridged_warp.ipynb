# %% [markdown]
# # They say it's ridged

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.ridged_warp(fabio)
save("assets/ridged_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.255,0.341,0.4)    …  RGB{N0f8}(0.106,0.157,0.188)
#  RGB{N0f8}(0.231,0.322,0.376)     RGB{N0f8}(0.122,0.173,0.204)
#  RGB{N0f8}(0.22,0.306,0.38)       RGB{N0f8}(0.129,0.18,0.212)
#  RGB{N0f8}(0.235,0.31,0.392)      RGB{N0f8}(0.125,0.176,0.212)
#  RGB{N0f8}(0.275,0.337,0.396)     RGB{N0f8}(0.118,0.169,0.204)
#  RGB{N0f8}(0.263,0.337,0.38)   …  RGB{N0f8}(0.118,0.169,0.204)
#  RGB{N0f8}(0.263,0.337,0.392)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.271,0.345,0.392)     RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.275,0.345,0.392)     RGB{N0f8}(0.118,0.176,0.208)
#  RGB{N0f8}(0.267,0.337,0.392)     RGB{N0f8}(0.122,0.176,0.208)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.769,0.631,0.49)      RGB{N0f8}(0.792,0.447,0.31)
#  RGB{N0f8}(0.773,0.667,0.541)     RGB{N0f8}(0.729,0.412,0.31)
#  RGB{N0f8}(0.784,0.682,0.553)     RGB{N0f8}(0.702,0.384,0.294)
#  RGB{N0f8}(0.718,0.569,0.439)  …  RGB{N0f8}(0.863,0.486,0.349)
#  RGB{N0f8}(0.792,0.69,0.51)       RGB{N0f8}(0.843,0.427,0.282)
#  RGB{N0f8}(0.773,0.682,0.451)     RGB{N0f8}(0.843,0.459,0.318)
#  RGB{N0f8}(0.741,0.604,0.365)     RGB{N0f8}(0.847,0.475,0.337)
#  RGB{N0f8}(0.776,0.624,0.431)     RGB{N0f8}(0.851,0.467,0.333)
#  RGB{N0f8}(0.914,0.827,0.729)  …  RGB{N0f8}(0.867,0.467,0.337)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
