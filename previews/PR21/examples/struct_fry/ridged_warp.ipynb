# %% [markdown]
# # They say it's ridged

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.ridged_warp(fabio)
save("assets/ridged_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.184,0.271,0.325)  …  RGB{N0f8}(0.129,0.176,0.224)
#  RGB{N0f8}(0.196,0.278,0.341)     RGB{N0f8}(0.125,0.176,0.212)
#  RGB{N0f8}(0.231,0.31,0.373)      RGB{N0f8}(0.125,0.176,0.212)
#  RGB{N0f8}(0.263,0.333,0.4)       RGB{N0f8}(0.125,0.173,0.212)
#  RGB{N0f8}(0.267,0.333,0.408)     RGB{N0f8}(0.129,0.169,0.208)
#  RGB{N0f8}(0.251,0.318,0.384)  …  RGB{N0f8}(0.133,0.18,0.22)
#  RGB{N0f8}(0.275,0.345,0.38)      RGB{N0f8}(0.129,0.176,0.224)
#  RGB{N0f8}(0.278,0.341,0.384)     RGB{N0f8}(0.125,0.176,0.216)
#  RGB{N0f8}(0.275,0.329,0.38)      RGB{N0f8}(0.122,0.176,0.212)
#  RGB{N0f8}(0.278,0.333,0.373)     RGB{N0f8}(0.125,0.18,0.216)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.78,0.647,0.475)      RGB{N0f8}(0.835,0.427,0.298)
#  RGB{N0f8}(0.792,0.647,0.451)     RGB{N0f8}(0.839,0.447,0.302)
#  RGB{N0f8}(0.8,0.631,0.451)       RGB{N0f8}(0.808,0.443,0.302)
#  RGB{N0f8}(0.831,0.694,0.604)  …  RGB{N0f8}(0.741,0.369,0.263)
#  RGB{N0f8}(0.855,0.725,0.584)     RGB{N0f8}(0.784,0.42,0.294)
#  RGB{N0f8}(0.863,0.714,0.549)     RGB{N0f8}(0.788,0.416,0.267)
#  RGB{N0f8}(0.812,0.667,0.478)     RGB{N0f8}(0.831,0.459,0.29)
#  RGB{N0f8}(0.757,0.608,0.408)     RGB{N0f8}(0.867,0.494,0.31)
#  RGB{N0f8}(0.761,0.576,0.384)  …  RGB{N0f8}(0.843,0.463,0.267)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
