# %% [markdown]
# # Cows are spherical

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sphere_warp(fabio)
save("assets/sphere_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.259,0.333,0.392)  …  RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.255,0.329,0.388)     RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.243,0.318,0.376)     RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.231,0.31,0.369)      RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.224,0.306,0.361)     RGB{N0f8}(0.125,0.18,0.216)
#  RGB{N0f8}(0.216,0.302,0.357)  …  RGB{N0f8}(0.129,0.184,0.22)
#  RGB{N0f8}(0.216,0.302,0.357)     RGB{N0f8}(0.129,0.184,0.216)
#  RGB{N0f8}(0.212,0.298,0.353)     RGB{N0f8}(0.129,0.18,0.212)
#  RGB{N0f8}(0.212,0.298,0.353)     RGB{N0f8}(0.129,0.18,0.212)
#  RGB{N0f8}(0.208,0.294,0.349)     RGB{N0f8}(0.125,0.176,0.208)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.718,0.58,0.376)      RGB{N0f8}(0.765,0.384,0.259)
#  RGB{N0f8}(0.722,0.592,0.4)       RGB{N0f8}(0.788,0.388,0.243)
#  RGB{N0f8}(0.733,0.616,0.439)     RGB{N0f8}(0.808,0.388,0.243)
#  RGB{N0f8}(0.745,0.624,0.447)  …  RGB{N0f8}(0.831,0.416,0.271)
#  RGB{N0f8}(0.796,0.647,0.475)     RGB{N0f8}(0.843,0.439,0.31)
#  RGB{N0f8}(0.867,0.741,0.608)     RGB{N0f8}(0.863,0.482,0.373)
#  RGB{N0f8}(0.898,0.8,0.69)        RGB{N0f8}(0.863,0.494,0.361)
#  RGB{N0f8}(0.863,0.773,0.647)     RGB{N0f8}(0.855,0.494,0.322)
#  RGB{N0f8}(0.773,0.655,0.475)  …  RGB{N0f8}(0.871,0.51,0.322)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
