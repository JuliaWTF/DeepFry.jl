# %% [markdown]
# # Gaussian filtering

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_filter(fabio)
save("assets/gauss_filter.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.482,0.42,0.412)   …  RGB{N0f8}(0.145,0.196,0.231)
#  RGB{N0f8}(0.478,0.408,0.396)     RGB{N0f8}(0.145,0.196,0.231)
#  RGB{N0f8}(0.471,0.396,0.38)      RGB{N0f8}(0.141,0.196,0.231)
#  RGB{N0f8}(0.467,0.384,0.369)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.459,0.376,0.353)     RGB{N0f8}(0.141,0.192,0.227)
#  RGB{N0f8}(0.455,0.369,0.341)  …  RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.451,0.361,0.333)     RGB{N0f8}(0.137,0.188,0.224)
#  RGB{N0f8}(0.447,0.353,0.325)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.443,0.349,0.318)     RGB{N0f8}(0.133,0.184,0.22)
#  RGB{N0f8}(0.439,0.349,0.314)     RGB{N0f8}(0.129,0.18,0.216)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.718,0.631,0.533)     RGB{N0f8}(0.8,0.478,0.369)
#  RGB{N0f8}(0.71,0.627,0.525)      RGB{N0f8}(0.824,0.494,0.38)
#  RGB{N0f8}(0.706,0.624,0.522)     RGB{N0f8}(0.847,0.51,0.392)
#  RGB{N0f8}(0.702,0.62,0.518)   …  RGB{N0f8}(0.863,0.522,0.4)
#  RGB{N0f8}(0.702,0.62,0.51)       RGB{N0f8}(0.875,0.533,0.408)
#  RGB{N0f8}(0.702,0.62,0.51)       RGB{N0f8}(0.882,0.545,0.412)
#  RGB{N0f8}(0.702,0.62,0.506)      RGB{N0f8}(0.89,0.553,0.416)
#  RGB{N0f8}(0.706,0.624,0.506)     RGB{N0f8}(0.898,0.557,0.42)
#  RGB{N0f8}(0.706,0.624,0.502)  …  RGB{N0f8}(0.902,0.565,0.42)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
