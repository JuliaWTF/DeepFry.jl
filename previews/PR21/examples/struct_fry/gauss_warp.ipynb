# %% [markdown]
# # Bubble like Gauss

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_warp(fabio)
save("assets/gauss_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.235,0.231,0.251)  …  RGB{N0f8}(0.671,0.643,0.557)
#  RGB{N0f8}(0.239,0.235,0.255)     RGB{N0f8}(0.663,0.639,0.549)
#  RGB{N0f8}(0.243,0.239,0.259)     RGB{N0f8}(0.663,0.639,0.545)
#  RGB{N0f8}(0.243,0.239,0.259)     RGB{N0f8}(0.655,0.635,0.537)
#  RGB{N0f8}(0.239,0.239,0.259)     RGB{N0f8}(0.631,0.62,0.518)
#  RGB{N0f8}(0.239,0.243,0.259)  …  RGB{N0f8}(0.62,0.612,0.506)
#  RGB{N0f8}(0.239,0.247,0.267)     RGB{N0f8}(0.612,0.612,0.502)
#  RGB{N0f8}(0.243,0.255,0.275)     RGB{N0f8}(0.612,0.62,0.506)
#  RGB{N0f8}(0.255,0.271,0.286)     RGB{N0f8}(0.62,0.631,0.518)
#  RGB{N0f8}(0.263,0.282,0.298)     RGB{N0f8}(0.6,0.608,0.498)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.169,0.216,0.263)     RGB{N0f8}(0.365,0.384,0.4)
#  RGB{N0f8}(0.129,0.184,0.227)     RGB{N0f8}(0.353,0.365,0.384)
#  RGB{N0f8}(0.09,0.153,0.192)      RGB{N0f8}(0.341,0.349,0.365)
#  RGB{N0f8}(0.09,0.157,0.196)   …  RGB{N0f8}(0.329,0.329,0.345)
#  RGB{N0f8}(0.098,0.169,0.2)       RGB{N0f8}(0.322,0.318,0.333)
#  RGB{N0f8}(0.114,0.176,0.212)     RGB{N0f8}(0.314,0.306,0.322)
#  RGB{N0f8}(0.129,0.184,0.216)     RGB{N0f8}(0.31,0.298,0.318)
#  RGB{N0f8}(0.133,0.184,0.216)     RGB{N0f8}(0.306,0.306,0.322)
#  RGB{N0f8}(0.133,0.184,0.212)  …  RGB{N0f8}(0.306,0.31,0.325)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
