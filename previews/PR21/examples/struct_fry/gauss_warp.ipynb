# %% [markdown]
# # Bubble like Gauss

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gauss_warp(fabio)
save("assets/gauss_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.208,0.243,0.278)  …  RGB{N0f8}(0.212,0.231,0.243)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.227,0.239)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.204,0.227,0.239)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.2,0.224,0.235)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.2,0.224,0.235)
#  RGB{N0f8}(0.208,0.243,0.278)  …  RGB{N0f8}(0.196,0.22,0.231)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.192,0.216,0.231)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.192,0.216,0.227)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.188,0.212,0.227)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.188,0.212,0.224)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)  …  RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)     RGB{N0f8}(0.208,0.243,0.278)
#  RGB{N0f8}(0.208,0.243,0.278)  …  RGB{N0f8}(0.208,0.243,0.278)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
