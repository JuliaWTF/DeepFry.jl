# %% [markdown]
# # Laplace like bubble

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.laplace_warp(fabio)
save("assets/laplace_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.208,0.239,0.251)  …  RGB{N0f8}(0.373,0.376,0.361)
#  RGB{N0f8}(0.216,0.243,0.251)     RGB{N0f8}(0.341,0.341,0.341)
#  RGB{N0f8}(0.224,0.247,0.255)     RGB{N0f8}(0.314,0.314,0.325)
#  RGB{N0f8}(0.231,0.255,0.259)     RGB{N0f8}(0.286,0.286,0.302)
#  RGB{N0f8}(0.239,0.263,0.267)     RGB{N0f8}(0.255,0.259,0.278)
#  RGB{N0f8}(0.243,0.267,0.275)  …  RGB{N0f8}(0.231,0.243,0.263)
#  RGB{N0f8}(0.247,0.271,0.275)     RGB{N0f8}(0.216,0.231,0.255)
#  RGB{N0f8}(0.251,0.275,0.275)     RGB{N0f8}(0.2,0.224,0.247)
#  RGB{N0f8}(0.259,0.278,0.278)     RGB{N0f8}(0.18,0.212,0.239)
#  RGB{N0f8}(0.267,0.282,0.282)     RGB{N0f8}(0.165,0.204,0.227)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.282,0.302,0.282)     RGB{N0f8}(0.988,0.839,0.773)
#  RGB{N0f8}(0.286,0.298,0.278)     RGB{N0f8}(0.992,0.839,0.776)
#  RGB{N0f8}(0.286,0.294,0.275)     RGB{N0f8}(0.992,0.839,0.78)
#  RGB{N0f8}(0.286,0.29,0.271)   …  RGB{N0f8}(0.992,0.839,0.773)
#  RGB{N0f8}(0.29,0.29,0.267)       RGB{N0f8}(0.996,0.839,0.769)
#  RGB{N0f8}(0.294,0.29,0.271)      RGB{N0f8}(0.996,0.839,0.765)
#  RGB{N0f8}(0.302,0.294,0.271)     RGB{N0f8}(1.0,0.839,0.761)
#  RGB{N0f8}(0.31,0.298,0.271)      RGB{N0f8}(1.0,0.839,0.757)
#  RGB{N0f8}(0.314,0.298,0.271)  …  RGB{N0f8}(1.0,0.839,0.749)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
