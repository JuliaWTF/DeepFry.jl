# %% [markdown]
# # Laplace like bubble

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.laplace_warp(fabio)
save("assets/laplace_warp.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(1.0,0.792,0.702)    …  RGB{N0f8}(0.769,0.404,0.267)
#  RGB{N0f8}(1.0,0.792,0.702)       RGB{N0f8}(0.761,0.396,0.263)
#  RGB{N0f8}(1.0,0.792,0.702)       RGB{N0f8}(0.753,0.392,0.263)
#  RGB{N0f8}(1.0,0.792,0.698)       RGB{N0f8}(0.745,0.384,0.263)
#  RGB{N0f8}(1.0,0.796,0.698)       RGB{N0f8}(0.729,0.376,0.259)
#  RGB{N0f8}(1.0,0.796,0.694)    …  RGB{N0f8}(0.714,0.365,0.255)
#  RGB{N0f8}(1.0,0.796,0.694)       RGB{N0f8}(0.702,0.353,0.251)
#  RGB{N0f8}(1.0,0.796,0.69)        RGB{N0f8}(0.686,0.345,0.247)
#  RGB{N0f8}(1.0,0.8,0.69)          RGB{N0f8}(0.675,0.333,0.239)
#  RGB{N0f8}(1.0,0.8,0.686)         RGB{N0f8}(0.663,0.322,0.235)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.8,0.573,0.451)       RGB{N0f8}(0.902,0.553,0.369)
#  RGB{N0f8}(0.796,0.569,0.459)     RGB{N0f8}(0.91,0.557,0.373)
#  RGB{N0f8}(0.792,0.565,0.467)     RGB{N0f8}(0.914,0.565,0.38)
#  RGB{N0f8}(0.788,0.561,0.478)  …  RGB{N0f8}(0.918,0.569,0.384)
#  RGB{N0f8}(0.788,0.553,0.486)     RGB{N0f8}(0.922,0.573,0.388)
#  RGB{N0f8}(0.784,0.549,0.494)     RGB{N0f8}(0.929,0.58,0.392)
#  RGB{N0f8}(0.78,0.545,0.502)      RGB{N0f8}(0.933,0.588,0.4)
#  RGB{N0f8}(0.78,0.541,0.514)      RGB{N0f8}(0.933,0.592,0.404)
#  RGB{N0f8}(0.78,0.541,0.51)    …  RGB{N0f8}(0.933,0.596,0.408)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
